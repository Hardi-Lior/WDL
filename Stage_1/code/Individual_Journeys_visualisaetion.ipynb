# %% [markdown]
# # Data exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
# helps to plot graphs in line with code-cells 

import seaborn as sns

# %% [markdown]
# ## 1. Importing the data

# %%
root_URL = 'https://raw.githubusercontent.com/StevenVuong/WDL_2020/master/data/stage1'
Individual_journeys_file ='Individual_journeys.csv'

Individual_journeys_URL = 'https://raw.githubusercontent.com/Hardi-Lior/WDL/main/Stage_1/data/Individual_journeys.csv'
# root_URL +'/'+ Individual_journeys_file

# %%
df = pd.read_csv(Individual_journeys_URL)

# %%
df.head()

# %%
df1.info()

# %% [markdown]
# # Perlimanary analisys

# %%
sns.set_theme(style="ticks")
sns.pairplot(df)#, hue="species")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-29d1c4ad76f9> in <module>()
#       1
#       2 sns.set_theme(style="ticks")
# ----> 3 sns.pairplot(df)#, hue="species")
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2030     if kind == "scatter":
#    2031         from .relational import scatterplot  # Avoid circular import
# -> 2032         plotter(scatterplot, **plot_kws)
#    2033     elif kind == "reg":
# ...
